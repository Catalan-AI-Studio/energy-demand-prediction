# %%
import pandas as pd
file1= r'/Users/caoguangjing/Desktop/catalan.ai/data/ercot_gen_all_15min_2024Q1.csv'
fuel_mix_generation_2024Q1 = pd.read_csv(file1, skiprows=3)
fuel_mix_generation_2024Q1.head()
# Out:
#   UTC Timestamp (Interval Ending)  \
# 0             2024-01-01 06:15:00
# 1             2024-01-01 06:30:00
# 2             2024-01-01 06:45:00
# 3             2024-01-01 07:00:00
# 4             2024-01-01 07:15:00
#
#   Local Timestamp Central Time (Interval Beginning)  \
# 0                               2024-01-01 00:00:00
# 1                               2024-01-01 00:15:00
# 2                               2024-01-01 00:30:00
# 3                               2024-01-01 00:45:00
# 4                               2024-01-01 01:00:00
#
#   Local Timestamp Central Time (Interval Ending)  Local Date  Hour Number  \
# 0                            2024-01-01 00:15:00  2024-01-01            1
# 1                            2024-01-01 00:30:00  2024-01-01            1
# 2                            2024-01-01 00:45:00  2024-01-01            1
# 3                            2024-01-01 01:00:00  2024-01-01            1
# ...

# %%
fuel_mix_generation_2024Q1.columns
# Out:
# Index(['UTC Timestamp (Interval Ending)',
#        'Local Timestamp Central Time (Interval Beginning)',
#        'Local Timestamp Central Time (Interval Ending)', 'Local Date',
#        'Hour Number', 'Total Generation (MW)', 'Biomass Generation (MW)',
#        'Coal Generation (MW)', 'Gas Generation (MW)', 'Gas-CC Generation (MW)',
#        'Hydro Generation (MW)', 'Nuclear Generation (MW)',
#        'Other Generation (MW)', 'Solar Generation (MW)', 'WSL Generation (MW)',
#        'Wind Generation (MW)'],
#       dtype='object')

# %%
fuel_mix_generation_2024Q1.shape
# Out:
# (8732, 16)

# %%
file2= r'/Users/caoguangjing/Desktop/catalan.ai/data/ercot_lmp_rt_15min_hubs_2024Q1.csv'
locational_marginal_prices_2024Q1 = pd.read_csv(file2, skiprows=3)
locational_marginal_prices_2024Q1.head()
# Out:
#   UTC Timestamp (Interval Ending)  \
# 0             2024-01-01 06:15:00
# 1             2024-01-01 06:30:00
# 2             2024-01-01 06:45:00
# 3             2024-01-01 07:00:00
# 4             2024-01-01 07:15:00
#
#   Local Timestamp Central Time (Interval Beginning)  \
# 0                               2024-01-01 00:00:00
# 1                               2024-01-01 00:15:00
# 2                               2024-01-01 00:30:00
# 3                               2024-01-01 00:45:00
# 4                               2024-01-01 01:00:00
#
#   Local Timestamp Central Time (Interval Ending)  Local Date  Hour Number  \
# 0                            2024-01-01 00:15:00  2024-01-01            1
# 1                            2024-01-01 00:30:00  2024-01-01            1
# 2                            2024-01-01 00:45:00  2024-01-01            1
# 3                            2024-01-01 01:00:00  2024-01-01            1
# ...

# %%
locational_marginal_prices_2024Q1.columns
# Out:
# Index(['UTC Timestamp (Interval Ending)',
#        'Local Timestamp Central Time (Interval Beginning)',
#        'Local Timestamp Central Time (Interval Ending)', 'Local Date',
#        'Hour Number', 'Bus average LMP', 'Houston LMP', 'Hub average LMP',
#        'North LMP', 'Panhandle LMP', 'South LMP', 'West LMP'],
#       dtype='object')

# %%
file3= r'/Users/caoguangjing/Desktop/catalan.ai/data/ercot_gen_sun-wnd_5min_2024Q1.csv'
sunwnd_5min_2024Q1 = pd.read_csv(file3, skiprows=3)
sunwnd_5min_2024Q1.head()
# Out:
#   UTC Timestamp (Interval Ending)  \
# 0             2024-01-01 06:05:00
# 1             2024-01-01 06:10:00
# 2             2024-01-01 06:15:00
# 3             2024-01-01 06:20:00
# 4             2024-01-01 06:25:00
#
#   Local Timestamp Central Time (Interval Beginning)  \
# 0                               2024-01-01 00:00:00
# 1                               2024-01-01 00:05:00
# 2                               2024-01-01 00:10:00
# 3                               2024-01-01 00:15:00
# 4                               2024-01-01 00:20:00
#
#   Local Timestamp Central Time (Interval Ending)  Local Date  Hour Number  \
# 0                            2024-01-01 00:05:00  2024-01-01            1
# 1                            2024-01-01 00:10:00  2024-01-01            1
# 2                            2024-01-01 00:15:00  2024-01-01            1
# 3                            2024-01-01 00:20:00  2024-01-01            1
# ...

# %%
sunwnd_5min_2024Q1.columns
# Out:
# Index(['UTC Timestamp (Interval Ending)',
#        'Local Timestamp Central Time (Interval Beginning)',
#        'Local Timestamp Central Time (Interval Ending)', 'Local Date',
#        'Hour Number', 'ERCOT Total Solar Generation (MW)',
#        'ERCOT Total Wind Generation (MW)', 'North Wind Generation (MW)',
#        'South Houston Wind Generation (MW)', 'West Wind Generation (MW)'],
#       dtype='object')

# %%
file4= r'/Users/caoguangjing/Desktop/catalan.ai/data/ercot_load_act_hr_2024.csv'
hourly_actual_load_2024 = pd.read_csv(file4, skiprows=3)
hourly_actual_load_2024.head()
# Out:
#   UTC Timestamp (Interval Ending)  \
# 0             2024-01-01 07:00:00
# 1             2024-01-01 08:00:00
# 2             2024-01-01 09:00:00
# 3             2024-01-01 10:00:00
# 4             2024-01-01 11:00:00
#
#   Local Timestamp Central Time (Interval Beginning)  \
# 0                               2024-01-01 00:00:00
# 1                               2024-01-01 01:00:00
# 2                               2024-01-01 02:00:00
# 3                               2024-01-01 03:00:00
# 4                               2024-01-01 04:00:00
#
#   Local Timestamp Central Time (Interval Ending)  Local Date  Hour Number  \
# 0                            2024-01-01 01:00:00  2024-01-01            1
# 1                            2024-01-01 02:00:00  2024-01-01            2
# 2                            2024-01-01 03:00:00  2024-01-01            3
# 3                            2024-01-01 04:00:00  2024-01-01            4
# ...

# %%
hourly_actual_load_2024.columns
# Out:
# Index(['UTC Timestamp (Interval Ending)',
#        'Local Timestamp Central Time (Interval Beginning)',
#        'Local Timestamp Central Time (Interval Ending)', 'Local Date',
#        'Hour Number', 'TOTAL Actual Load (MW)', 'Coast Actual Load (MW)',
#        'East Actual Load (MW)', 'Far West Actual Load (MW)',
#        'North Actual Load (MW)', 'North Central Actual Load (MW)',
#        'Southern Actual Load (MW)', 'South Central Actual Load (MW)',
#        'West Actual Load (MW)'],
#       dtype='object')

# %%
file5= r'/Users/caoguangjing/Desktop/catalan.ai/data/ercot_lmp_da_hr_hubs_2024.csv'
lmp_da_hr_hubs_2024 = pd.read_csv(file5, skiprows=3)
lmp_da_hr_hubs_2024.head()
# Out:
#   UTC Timestamp (Interval Ending)  \
# 0             2024-01-01 07:00:00
# 1             2024-01-01 08:00:00
# 2             2024-01-01 09:00:00
# 3             2024-01-01 10:00:00
# 4             2024-01-01 11:00:00
#
#   Local Timestamp Central Time (Interval Beginning)  \
# 0                               2024-01-01 00:00:00
# 1                               2024-01-01 01:00:00
# 2                               2024-01-01 02:00:00
# 3                               2024-01-01 03:00:00
# 4                               2024-01-01 04:00:00
#
#   Local Timestamp Central Time (Interval Ending)  Local Date  Hour Number  \
# 0                            2024-01-01 01:00:00  2024-01-01            1
# 1                            2024-01-01 02:00:00  2024-01-01            2
# 2                            2024-01-01 03:00:00  2024-01-01            3
# 3                            2024-01-01 04:00:00  2024-01-01            4
# ...

# %%
lmp_da_hr_hubs_2024.columns
# Out:
# Index(['UTC Timestamp (Interval Ending)',
#        'Local Timestamp Central Time (Interval Beginning)',
#        'Local Timestamp Central Time (Interval Ending)', 'Local Date',
#        'Hour Number', 'Bus average LMP', 'Houston LMP', 'Hub average LMP',
#        'North LMP', 'Panhandle LMP', 'South LMP', 'West LMP'],
#       dtype='object')

# %%
file6= r'/Users/caoguangjing/Desktop/catalan.ai/data/ercot_load_for_hr_2024.csv'
ercot_load_for_hr_2024 = pd.read_csv(file6, skiprows=3)
ercot_load_for_hr_2024.head()
# Out:
#   UTC Timestamp (Interval Ending)  \
# 0             2024-01-01 07:00:00
# 1             2024-01-01 08:00:00
# 2             2024-01-01 09:00:00
# 3             2024-01-01 10:00:00
# 4             2024-01-01 11:00:00
#
#   Local Timestamp Central Time (Interval Beginning)  \
# 0                               2024-01-01 00:00:00
# 1                               2024-01-01 01:00:00
# 2                               2024-01-01 02:00:00
# 3                               2024-01-01 03:00:00
# 4                               2024-01-01 04:00:00
#
#   Local Timestamp Central Time (Interval Ending)  Local Date  Hour Number  \
# 0                            2024-01-01 01:00:00  2024-01-01            1
# 1                            2024-01-01 02:00:00  2024-01-01            2
# 2                            2024-01-01 03:00:00  2024-01-01            3
# 3                            2024-01-01 04:00:00  2024-01-01            4
# ...

# %%
ercot_load_for_hr_2024.columns
# Out:
# Index(['UTC Timestamp (Interval Ending)',
#        'Local Timestamp Central Time (Interval Beginning)',
#        'Local Timestamp Central Time (Interval Ending)', 'Local Date',
#        'Hour Number', 'SystemTotal Forecast Load (MW)',
#        'Houston Forecast Load (MW)', 'North Forecast Load (MW)',
#        'South Forecast Load (MW)', 'West Forecast Load (MW)'],
#       dtype='object')

# %%
file7= r'/Users/caoguangjing/Desktop/catalan.ai/data/ercot_int_all_hr_2024.csv'
ercot_int_all_hr_2024 = pd.read_csv(file7, skiprows=3)
ercot_int_all_hr_2024.head()
# Out:
#   UTC Timestamp (Interval Ending)  \
# 0             2024-01-01 06:09:53
# 1             2024-01-01 07:09:53
# 2             2024-01-01 08:09:53
# 3             2024-01-01 09:09:53
# 4             2024-01-01 10:09:53
#
#   Local Timestamp Central Time (Interval Beginning)  \
# 0                               2024-01-01 00:09:53
# 1                               2024-01-01 01:09:53
# 2                               2024-01-01 02:09:53
# 3                               2024-01-01 03:09:53
# 4                               2024-01-01 04:09:53
#
#   Local Timestamp Central Time (Interval Ending)  Local Date  Hour Number  \
# 0                            2024-01-01 00:09:53  2024-01-01            2
# 1                            2024-01-01 01:09:53  2024-01-01            3
# 2                            2024-01-01 02:09:53  2024-01-01            4
# 3                            2024-01-01 03:09:53  2024-01-01            5
# ...

# %%
ercot_int_all_hr_2024.columns
# Out:
# Index(['UTC Timestamp (Interval Ending)',
#        'Local Timestamp Central Time (Interval Beginning)',
#        'Local Timestamp Central Time (Interval Ending)', 'Local Date',
#        'Hour Number',
#        'Comision Federal de Electricidad, Laredo Net Export (MW)',
#        'Comision Federal de Electricidad, Railroad Net Export (MW)',
#        'Southwest Power Pool, East Net Export (MW)',
#        'Southwest Power Pool, North Net Export (MW)'],
#       dtype='object')

# %%
file8= r'/Users/caoguangjing/Desktop/catalan.ai/data/ercot_load-temp_hr_2024.csv'
load_temp_hr_2024 = pd.read_csv(file8, skiprows=3)
load_temp_hr_2024.head()
# Out:
#   UTC Timestamp (Interval Ending)  \
# 0             2024-01-01 07:00:00
# 1             2024-01-01 08:00:00
# 2             2024-01-01 09:00:00
# 3             2024-01-01 10:00:00
# 4             2024-01-01 11:00:00
#
#   Local Timestamp Central Time (Interval Beginning)  \
# 0                               2024-01-01 00:00:00
# 1                               2024-01-01 01:00:00
# 2                               2024-01-01 02:00:00
# 3                               2024-01-01 03:00:00
# 4                               2024-01-01 04:00:00
#
#   Local Timestamp Central Time (Interval Ending)  Local Date  Hour Number  \
# 0                            2024-01-01 01:00:00  2024-01-01            1
# 1                            2024-01-01 02:00:00  2024-01-01            2
# 2                            2024-01-01 03:00:00  2024-01-01            3
# 3                            2024-01-01 04:00:00  2024-01-01            4
# ...

# %%
load_temp_hr_2024.columns
# Out:
# Index(['UTC Timestamp (Interval Ending)',
#        'Local Timestamp Central Time (Interval Beginning)',
#        'Local Timestamp Central Time (Interval Ending)', 'Local Date',
#        'Hour Number', 'TOTAL Actual Load (MW)',
#        'SystemTotal Forecast Load (MW)', 'Coast Actual Load (MW)',
#        'East Actual Load (MW)', 'Far West Actual Load (MW)',
#        'North Actual Load (MW)', 'North Central Actual Load (MW)',
#        'South Central Actual Load (MW)', 'Southern Actual Load (MW)',
#        'West Actual Load (MW)', 'Houston Forecast Load (MW)',
#        'North Forecast Load (MW)', 'South Forecast Load (MW)',
#        'West Forecast Load (MW)',
#        'Dallas / Fort Worth Temperature (Fahrenheit)',
#        'Dallas / Fort Worth Temperature Observation Time (Central)',
#        'Houston International Airport Temperature (Fahrenheit)',
#        'Houston International Airport Temperature Observation Time (Central)'],
#       dtype='object')

# %%
file9= r'/Users/caoguangjing/Desktop/catalan.ai/data/ercot_gen_sun-wnd_hr_2024.csv'
ercot_gen_sun_wnd_hr_2024 = pd.read_csv(file9, skiprows=3)
ercot_gen_sun_wnd_hr_2024.head()
# Out:
#   UTC Timestamp (Interval Ending)  \
# 0             2024-01-01 07:00:00
# 1             2024-01-01 08:00:00
# 2             2024-01-01 09:00:00
# 3             2024-01-01 10:00:00
# 4             2024-01-01 11:00:00
#
#   Local Timestamp Central Time (Interval Beginning)  \
# 0                               2024-01-01 00:00:00
# 1                               2024-01-01 01:00:00
# 2                               2024-01-01 02:00:00
# 3                               2024-01-01 03:00:00
# 4                               2024-01-01 04:00:00
#
#   Local Timestamp Central Time (Interval Ending)  Local Date  Hour Number  \
# 0                            2024-01-01 01:00:00  2024-01-01            1
# 1                            2024-01-01 02:00:00  2024-01-01            2
# 2                            2024-01-01 03:00:00  2024-01-01            3
# 3                            2024-01-01 04:00:00  2024-01-01            4
# ...

# %%
ercot_gen_sun_wnd_hr_2024.columns
# Out:
# Index(['UTC Timestamp (Interval Ending)',
#        'Local Timestamp Central Time (Interval Beginning)',
#        'Local Timestamp Central Time (Interval Ending)', 'Local Date',
#        'Hour Number', 'ERCOT Total Solar Generation (MW)',
#        'ERCOT Total Wind Generation (MW)', 'Coastal Wind Generation (MW)',
#        'North Wind Generation (MW)', 'Panhandle Wind Generation (MW)',
#        'South Wind Generation (MW)', 'West Wind Generation (MW)'],
#       dtype='object')

# %%
file10= r'/Users/caoguangjing/Desktop/catalan.ai/data/ercot_temp_hr_2024.csv'
ercot_temp_hr_2024 = pd.read_csv(file10, skiprows=3)
ercot_temp_hr_2024.head()
# Out:
#    Dallas / Fort Worth Temperature (Fahrenheit)  \
# 0                                          37.9
# 1                                          37.0
# 2                                          36.0
# 3                                          35.1
# 4                                          34.0
#
#   Dallas / Fort Worth Temperature Observation Time (Central)  \
# 0                                2024-01-01 00:53:00
# 1                                2024-01-01 01:53:00
# 2                                2024-01-01 02:53:00
# 3                                2024-01-01 03:53:00
# 4                                2024-01-01 04:53:00
#
#    Houston International Airport Temperature (Fahrenheit)  \
# 0                                               57.0
# 1                                               57.0
# 2                                               57.0
# 3                                               55.9
# 4                                               55.9
#
# ...

# %%
ercot_temp_hr_2024.columns
# Out:
# Index(['Dallas / Fort Worth Temperature (Fahrenheit)',
#        'Dallas / Fort Worth Temperature Observation Time (Central)',
#        'Houston International Airport Temperature (Fahrenheit)',
#        'Houston International Airport Temperature Observation Time (Central)',
#        'UTC Timestamp (Interval Ending)',
#        'Local Timestamp Central Time (Interval Beginning)',
#        'Local Timestamp Central Time (Interval Ending)', 'Local Date',
#        'Hour Number'],
#       dtype='object')

# %%
file= r'/Users/caoguangjing/Desktop/catalan.ai/data/ercot_load_act_hr_2023.csv'
df = pd.read_csv(file, skiprows=3)
df.head()
# Out:
#   UTC Timestamp (Interval Ending)  \
# 0             2023-01-01 07:00:00
# 1             2023-01-01 08:00:00
# 2             2023-01-01 09:00:00
# 3             2023-01-01 10:00:00
# 4             2023-01-01 11:00:00
#
#   Local Timestamp Central Time (Interval Beginning)  \
# 0                               2023-01-01 00:00:00
# 1                               2023-01-01 01:00:00
# 2                               2023-01-01 02:00:00
# 3                               2023-01-01 03:00:00
# 4                               2023-01-01 04:00:00
#
#   Local Timestamp Central Time (Interval Ending)  Local Date  Hour Number  \
# 0                            2023-01-01 01:00:00  2023-01-01            1
# 1                            2023-01-01 02:00:00  2023-01-01            2
# 2                            2023-01-01 03:00:00  2023-01-01            3
# 3                            2023-01-01 04:00:00  2023-01-01            4
# ...

# %%
df.shape
# Out:
# (7600, 14)

# %%
Y = df['TOTAL Actual Load (MW)']
